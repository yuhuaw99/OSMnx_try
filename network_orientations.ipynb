# %% [markdown]
# # Street network orientations

# %%
import matplotlib.pyplot as plt
import numpy as np
import osmnx as ox

weight_by_length = False

# %%
G = ox.load_graphml('./data/network_ch.graphml')

# %%
Gu = ox.bearing.add_edge_bearings(ox.convert.to_undirected(G))
fig, ax = ox.plot.plot_orientation(Gu, title='Chapel Hill', area=True)
